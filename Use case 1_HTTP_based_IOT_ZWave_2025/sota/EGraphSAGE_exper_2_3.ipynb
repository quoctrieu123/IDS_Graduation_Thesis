# %%
import pandas as pd
train_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_http\chunk-based-split-3\train_df_prepared.parquet", engine="pyarrow")
valid_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_http\chunk-based-split-3\valid_df_prepared.parquet", engine="pyarrow")
test_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_http\chunk-based-split-3\test_df_prepared.parquet", engine="pyarrow")

# %%
train_df["timestamp_num"] = pd.to_datetime(train_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9
valid_df["timestamp_num"] = pd.to_datetime(valid_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9
test_df["timestamp_num"] = pd.to_datetime(test_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9

# %%
train_df.sort_values(by='timestamp_num', inplace=True)
valid_df.sort_values(by='timestamp_num', inplace=True)
test_df.sort_values(by='timestamp_num', inplace=True)

# %% [markdown]
# ### 1. Chuẩn bị dữ liệu Đồ thị (Graph Data Preparation) cho PyG
# Chuyển đổi DataFrame thành cấu trúc `edge_index` và `edge_attr` của PyTorch Geometric.

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch_geometric.data import Data

print("--- BƯỚC 1: XỬ LÝ IP VÀ TẠO MAPPING ---")
all_ips = pd.concat([
    train_df['src_ip'], train_df['dst_ip'],
    valid_df['src_ip'], valid_df['dst_ip'],
    test_df['src_ip'], test_df['dst_ip']
]).unique()

ip_to_id = {ip: i for i, ip in enumerate(all_ips)}
num_nodes = len(all_ips)
print(f"Tổng số Nodes (IP duy nhất) trong toàn bộ dữ liệu: {num_nodes}")

def prepare_dynamic_graphs(df, ip_dict, window_size_sec=600):
    """Hàm CHUẨN MỰC: Cắt lược DataFrame thành mảng các Đồ thị theo Cửa sổ thời gian (Time-Windows)
       -> Giữ nguyên tính lịch sử thời gian, KO BỊ TEMPORAL LEAKAGE!"""
    min_time = df['timestamp_num'].min()
    
    # Tránh SettingWithCopyWarning
    df = df.copy()
    # Phân lô thời gian (VD: Cứ 600 giây thành 1 cục)
    df['time_window'] = ((df['timestamp_num'] - min_time) // window_size_sec).astype(int)
    
    dynamic_graphs = []
    cols_to_drop = ['flow_id', 'timestamp', 'timestamp_num', 'time_window', 'src_ip', 'dst_ip', 'protocol', 'src_port', 'dst_port', 'label']
    cols_to_drop = [c for c in cols_to_drop if c in df.columns]
    
    # Nhóm theo từng cửa sổ thời gian (Quá khứ -> Hiện tại -> Tương lai)
    for window_id, group in df.groupby('time_window'):
        if len(group) == 0:
            continue
            
        src_nodes = group['src_ip'].map(ip_dict).values
        dst_nodes = group['dst_ip'].map(ip_dict).values
        edge_index = torch.tensor(np.vstack([src_nodes, dst_nodes]), dtype=torch.long)
        
        edge_features = group.drop(columns=cols_to_drop).values
        edge_attr = torch.tensor(edge_features, dtype=torch.float32)
        
        labels = torch.tensor(group['label'].values, dtype=torch.long)
        
        # Bọc thành đối tượng PyG Data của KHUÔN HÌNH THỜI GIAN đó
        snapshot = Data(
            num_nodes=len(ip_dict), 
            edge_index=edge_index, 
            edge_attr=edge_attr, 
            y=labels
        )
        dynamic_graphs.append(snapshot)
        
    return dynamic_graphs

print("\n--- BƯỚC 2: CẮT ĐỒ THỊ THEO THỜI GIAN (TIME-WINDOW GRAPHS) ---")
WINDOW_SIZE = 600 # Nhóm từng khoảng 10 phút (600 giây) thành 1 đồ thị chuẩn
print(f"Đang tiến hành cắt đồ thị với cửa sổ {WINDOW_SIZE} giây / snapshot...")

train_graphs = prepare_dynamic_graphs(train_df, ip_to_id, WINDOW_SIZE)
valid_graphs = prepare_dynamic_graphs(valid_df, ip_to_id, WINDOW_SIZE)
test_graphs = prepare_dynamic_graphs(test_df, ip_to_id, WINDOW_SIZE)

print(f"-> Tập Train được cắt thành {len(train_graphs):,} Snapshots (Snapshot Đồ Thị Thời Gian)")
print(f"-> Tổng lưu lượng Edges trong Train: {sum([g.num_edges for g in train_graphs]):,}")
# Out:
# --- BƯỚC 1: XỬ LÝ IP VÀ TẠO MAPPING ---
# Tổng số Nodes (IP duy nhất) trong toàn bộ dữ liệu: 23
#
# --- BƯỚC 2: CẮT ĐỒ THỊ THEO THỜI GIAN (TIME-WINDOW GRAPHS) ---
# Đang tiến hành cắt đồ thị với cửa sổ 600 giây / snapshot...
# -> Tập Train được cắt thành 23 Snapshots (Snapshot Đồ Thị Thời Gian)
# -> Tổng lưu lượng Edges trong Train: 2,470,638

# %% [markdown]
# ### 2. Kiểm tra Đặc tính đồ thị (Graph Diagnostic Checks)
# Dùng PyTorch Geometric `Data` object để bọc dữ liệu và tiến hành check tính hợp lệ của đồ thị (Label Imbalance, NaNs/Infs, Self-loops...)

# %%
from torch_geometric.data import Data

print("--- BƯỚC 3: KIỂM TRA ĐẶC TÍNH CỦA ĐỒ THỊ THỜI GIAN (DIAGNOSTIC CHECKS) ---")

# Lấy thử Snapshot đầu tiên và Snapshot bất kỳ có nhiều luồng nhất để phân tích
max_edge_graph = max(train_graphs, key=lambda g: g.num_edges)
first_graph = train_graphs[0]

print(f"1. Cấu trúc tổng quát của MỘT SỐ Đồ thị con (Snapshot lớn nhất):")
print(f"   - Số lượng Nút (IP): {max_edge_graph.num_nodes:,} (Khung IP cố định)")
print(f"   - Số lượng Cạnh (Flows): {max_edge_graph.num_edges:,}")
print(f"   - Đồ thị có chứa vòng lặp (Self-loops): {max_edge_graph.has_self_loops()}")
print(f"   - Đồ thị có Nút cô lập (Isolated Nodes)? {max_edge_graph.has_isolated_nodes()}")

print("\n2. Kiểm tra tính hợp lệ của Feature trên Snapshot đầu tiên:")
has_nan = torch.isnan(first_graph.edge_attr).any().item()
has_inf = torch.isinf(first_graph.edge_attr).any().item()
print(f"   - Có chứa giá trị NaN? {'CÓ LỖI' if has_nan else 'Không (An toàn)'}")
print(f"   - Có chứa giá trị Inf? {'CÓ LỖI' if has_inf else 'Không (An toàn)'}")

print("\n3. Kiểm tra tính Đa đồ thị (Multi-graph) trong Snapshot 10 phút nhỏ này:")
unique_edges = torch.unique(max_edge_graph.edge_index, dim=1).shape[1]
duplicate_edges = max_edge_graph.num_edges - unique_edges
print(f"   - Số cạnh trùng lặp trên cùng cặp IP: {duplicate_edges:,} / {max_edge_graph.num_edges:,} flows")
if duplicate_edges > 0:
    print("   -> Snapshot trong 10 phút là Multi-graph, mô phỏng đúng Network Burst (Bùng nổ băng thông)!")
    print("   -> (Giải pháp E-GraphSAGE dùng aggr='max' đã được chuẩn bị để quét các tín hiệu ẩn)")

print("\n4. Kiểm tra phân phối Nhãn (Class Imbalance) trên toàn bộ các Snapshot Train:")
total_label_counts = torch.zeros(11, dtype=torch.int64) # Giả sử có tối đa 11 classes, điều chỉnh số liệu nếu cần
total_edges = sum([g.num_edges for g in train_graphs])

for g in train_graphs:
    counts = torch.bincount(g.y, minlength=11)
    total_label_counts += counts

for i, count in enumerate(total_label_counts[:11]):
    if count > 0:
        percentage = (count.item() / total_edges) * 100
        print(f"   - Lớp {i}: {count.item():>9,} flows ({percentage:>6.2f}%)")
# Out:
# --- BƯỚC 3: KIỂM TRA ĐẶC TÍNH CỦA ĐỒ THỊ THỜI GIAN (DIAGNOSTIC CHECKS) ---
# 1. Cấu trúc tổng quát của MỘT SỐ Đồ thị con (Snapshot lớn nhất):
#    - Số lượng Nút (IP): 23 (Khung IP cố định)
#    - Số lượng Cạnh (Flows): 689,408
#    - Đồ thị có chứa vòng lặp (Self-loops): False
#    - Đồ thị có Nút cô lập (Isolated Nodes)? True
#
# 2. Kiểm tra tính hợp lệ của Feature trên Snapshot đầu tiên:
#    - Có chứa giá trị NaN? Không (An toàn)
#    - Có chứa giá trị Inf? Không (An toàn)
#
# 3. Kiểm tra tính Đa đồ thị (Multi-graph) trong Snapshot 10 phút nhỏ này:
#    - Số cạnh trùng lặp trên cùng cặp IP: 689,387 / 689,408 flows
#    -> Snapshot trong 10 phút là Multi-graph, mô phỏng đúng Network Burst (Bùng nổ băng thông)!
#    -> (Giải pháp E-GraphSAGE dùng aggr='max' đã được chuẩn bị để quét các tín hiệu ẩn)
#
# 4. Kiểm tra phân phối Nhãn (Class Imbalance) trên toàn bộ các Snapshot Train:
#    - Lớp 0:    64,488 flows (  2.61%)
#    - Lớp 1: 1,573,220 flows ( 63.68%)
#    - Lớp 2:     8,164 flows (  0.33%)
#    - Lớp 3:   117,813 flows (  4.77%)
#    - Lớp 4:    61,666 flows (  2.50%)
#    - Lớp 5:     7,956 flows (  0.32%)
#    - Lớp 6:    38,490 flows (  1.56%)
#    - Lớp 7:   349,153 flows ( 14.13%)
#    - Lớp 8:    54,420 flows (  2.20%)
#    - Lớp 9:   134,940 flows (  5.46%)
#    - Lớp 10:    60,328 flows (  2.44%)

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing

# 1. ĐỊNH NGHĨA LỚP MESSAGE PASSING KẾT HỢP CẠNH (EDGE-ENHANCED SAGE)
class EdgeSAGEConv(MessagePassing):
    def __init__(self, in_channels, out_channels, edge_channels, dropout=0.2):
        # TỐI ƯU 1: Đổi từ 'mean' sang 'max' pooling
        # Vì data bị vón cục (nhiều flow cùng 1 class lấn át), 'mean' sẽ cào bằng làm tàng hình class phụ.
        # 'max' pooling giúp GraphSAGE bắt được tín hiệu của các luồng dị biệt (cực kỳ hiệu quả cho Intrusion Detection)
        super().__init__(aggr='max') 
        
        self.msg_mlp = nn.Sequential(
            nn.Linear(in_channels + edge_channels, out_channels),
            nn.LayerNorm(out_channels),
            nn.ReLU(),
            nn.Dropout(dropout) # Thêm nhiễu để bớt học vẹt bối cảnh hàng xóm
        )
        
        self.update_mlp = nn.Sequential(
            nn.Linear(in_channels + out_channels, out_channels),
            nn.LayerNorm(out_channels),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

    def forward(self, x, edge_index, edge_attr):
        return self.propagate(edge_index, x=x, edge_attr=edge_attr)

    def message(self, x_j, edge_attr):
        msg_input = torch.cat([x_j, edge_attr], dim=-1)
        return self.msg_mlp(msg_input)

    def update(self, aggr_out, x):
        update_input = torch.cat([x, aggr_out], dim=-1)
        return self.update_mlp(update_input)

# 2. ĐỊNH NGHĨA MODEL TỔNG THỂ 
class EGraphSAGE(nn.Module):
    def __init__(self, num_nodes, node_emb_dim, edge_in_dim, hidden_dim, num_classes):
        super().__init__()
        self.node_emb = nn.Embedding(num_nodes, node_emb_dim)
        
        self.edge_norm = nn.LayerNorm(edge_in_dim) 
        
        # Thêm dropout nhẹ vào Convolution
        self.conv1 = EdgeSAGEConv(node_emb_dim, hidden_dim, edge_in_dim, dropout=0.1)
        self.conv2 = EdgeSAGEConv(hidden_dim, hidden_dim, edge_in_dim, dropout=0.1)
        
        classifier_dim = hidden_dim * 2 + edge_in_dim
        self.classifier = nn.Sequential(
            nn.Linear(classifier_dim, hidden_dim * 2),
            nn.LayerNorm(hidden_dim * 2),
            nn.ReLU(),
            nn.Dropout(0.4), # Tăng Dropout tầng cuối để chống Overfitting
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(hidden_dim, num_classes)
        )

    def encode_context(self, edge_index, edge_attr):
        clean_attr = torch.nan_to_num(edge_attr, nan=0.0, posinf=0.0, neginf=0.0)
        clean_attr = self.edge_norm(clean_attr)
        
        x = self.node_emb.weight
        x = F.relu(self.conv1(x, edge_index, clean_attr))
        x = self.conv2(x, edge_index, clean_attr)
        return x, clean_attr

    def predict_edges(self, x_context, clean_attr, edge_index, query_idx):
        src_nodes = edge_index[0, query_idx]
        dst_nodes = edge_index[1, query_idx]
        batch_attr = clean_attr[query_idx]
        
        edge_repr = torch.cat([x_context[src_nodes], x_context[dst_nodes], batch_attr], dim=-1)
        return self.classifier(edge_repr)

print("Đã xây dựng xong Mô Hình SAGE (Tối ưu hóa Aggregation & Dropout)!")
# Out:
# Đã xây dựng xong Mô Hình SAGE (Tối ưu hóa Aggregation & Dropout)!

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 11

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 500.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.4735095  0.01940967 3.740284   0.2591877  0.49517855 3.8380697
#  0.7933406  0.08745643 0.56111133 0.2262908  0.506161  ]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 60
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 8        

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT CHO CẢ ĐỒ THỊ (TĂNG TỐC ĐỘ x20 LẦN!)
        x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER (Tránh Bể RAM)
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
            
            # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
            loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            loss.backward() # Chỉ chạy ngược từ Classifier tới x_ctx_det, SIÊU NHANH
            
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN 1 LẦN DUY NHẤT LÚC ĐÓNG CỬA SỔ
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
            
    avg_train_loss = total_train_loss / total_train_edges
    
    # Validation
    val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
    
    # Bóp Learning Rate dựa theo F1
    scheduler.step(val_f1)
    current_lr = optimizer.param_groups[0]['lr']
    
    print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
    
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        best_model_wts = copy.deepcopy(model.state_dict())
        patience_counter = 0
        print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
            break

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred = evaluate_graphs(model, test_graphs, criterion, device)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}\n")
print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 60 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...
# Epoch  1/60 | LR: 0.001000 | Train Loss: 7.2990 | Val Loss: 5.6398 | Val F1: 0.0783
#    -> Epoch 1: Kỷ lục F1 mới (0.0783)! Đã lưu trọng số.
# Epoch  2/60 | LR: 0.001000 | Train Loss: 5.6424 | Val Loss: 5.2293 | Val F1: 0.0818
#    -> Epoch 2: Kỷ lục F1 mới (0.0818)! Đã lưu trọng số.
# Epoch  3/60 | LR: 0.001000 | Train Loss: 5.4844 | Val Loss: 5.1451 | Val F1: 0.1723
#    -> Epoch 3: Kỷ lục F1 mới (0.1723)! Đã lưu trọng số.
# Epoch  4/60 | LR: 0.001000 | Train Loss: 5.3672 | Val Loss: 5.1040 | Val F1: 0.2002
#    -> Epoch 4: Kỷ lục F1 mới (0.2002)! Đã lưu trọng số.
# Epoch  5/60 | LR: 0.001000 | Train Loss: 5.2410 | Val Loss: 5.0271 | Val F1: 0.2257
#    -> Epoch 5: Kỷ lục F1 mới (0.2257)! Đã lưu trọng số.
# Epoch  6/60 | LR: 0.001000 | Train Loss: 5.1895 | Val Loss: 5.0077 | Val F1: 0.2513
#    -> Epoch 6: Kỷ lục F1 mới (0.2513)! Đã lưu trọng số.
# Epoch  7/60 | LR: 0.001000 | Train Loss: 5.1915 | Val Loss: 5.1318 | Val F1: 0.1096
# Epoch  8/60 | LR: 0.001000 | Train Loss: 5.1804 | Val Loss: 5.0068 | Val F1: 0.2188
# Epoch  9/60 | LR: 0.000500 | Train Loss: 5.0735 | Val Loss: 4.9611 | Val F1: 0.2002
# Epoch 10/60 | LR: 0.000500 | Train Loss: 5.0223 | Val Loss: 4.9545 | Val F1: 0.3668
#    -> Epoch 10: Kỷ lục F1 mới (0.3668)! Đã lưu trọng số.
# Epoch 11/60 | LR: 0.000500 | Train Loss: 5.0011 | Val Loss: 4.9166 | Val F1: 0.2584
# Epoch 12/60 | LR: 0.000500 | Train Loss: 4.9490 | Val Loss: 4.9348 | Val F1: 0.4189
#    -> Epoch 12: Kỷ lục F1 mới (0.4189)! Đã lưu trọng số.
# Epoch 13/60 | LR: 0.000500 | Train Loss: 4.9702 | Val Loss: 4.9241 | Val F1: 0.2989
# Epoch 14/60 | LR: 0.000500 | Train Loss: 4.9252 | Val Loss: 4.8960 | Val F1: 0.3064
# Epoch 15/60 | LR: 0.000250 | Train Loss: 4.8979 | Val Loss: 4.9136 | Val F1: 0.3925
# Epoch 16/60 | LR: 0.000250 | Train Loss: 4.8370 | Val Loss: 4.8955 | Val F1: 0.3805
# Epoch 17/60 | LR: 0.000250 | Train Loss: 4.8107 | Val Loss: 4.8843 | Val F1: 0.2915
# Epoch 18/60 | LR: 0.000125 | Train Loss: 4.7694 | Val Loss: 4.8746 | Val F1: 0.3324
# Epoch 19/60 | LR: 0.000125 | Train Loss: 4.7340 | Val Loss: 4.8694 | Val F1: 0.5306
#    -> Epoch 19: Kỷ lục F1 mới (0.5306)! Đã lưu trọng số.
# Epoch 20/60 | LR: 0.000125 | Train Loss: 4.7080 | Val Loss: 4.8691 | Val F1: 0.5155
# Epoch 21/60 | LR: 0.000125 | Train Loss: 4.6918 | Val Loss: 4.8698 | Val F1: 0.5326
#    -> Epoch 21: Kỷ lục F1 mới (0.5326)! Đã lưu trọng số.
# Epoch 22/60 | LR: 0.000125 | Train Loss: 4.6779 | Val Loss: 4.8533 | Val F1: 0.5395
#    -> Epoch 22: Kỷ lục F1 mới (0.5395)! Đã lưu trọng số.
# Epoch 23/60 | LR: 0.000125 | Train Loss: 4.6725 | Val Loss: 4.8601 | Val F1: 0.5189
# Epoch 24/60 | LR: 0.000125 | Train Loss: 4.6579 | Val Loss: 4.8799 | Val F1: 0.5251
# Epoch 25/60 | LR: 0.000125 | Train Loss: 4.6479 | Val Loss: 4.8412 | Val F1: 0.5655
#    -> Epoch 25: Kỷ lục F1 mới (0.5655)! Đã lưu trọng số.
# Epoch 26/60 | LR: 0.000125 | Train Loss: 4.6489 | Val Loss: 4.8564 | Val F1: 0.5167
# Epoch 27/60 | LR: 0.000125 | Train Loss: 4.6361 | Val Loss: 4.8521 | Val F1: 0.5502
# Epoch 28/60 | LR: 0.000063 | Train Loss: 4.6329 | Val Loss: 4.8623 | Val F1: 0.5368
# Epoch 29/60 | LR: 0.000063 | Train Loss: 4.6223 | Val Loss: 4.8520 | Val F1: 0.5434
# Epoch 30/60 | LR: 0.000063 | Train Loss: 4.6208 | Val Loss: 4.8494 | Val F1: 0.5452
# Epoch 31/60 | LR: 0.000031 | Train Loss: 4.6166 | Val Loss: 4.8640 | Val F1: 0.5502
# Epoch 32/60 | LR: 0.000031 | Train Loss: 4.6145 | Val Loss: 4.8526 | Val F1: 0.5617
# Epoch 33/60 | LR: 0.000031 | Train Loss: 4.6124 | Val Loss: 4.8567 | Val F1: 0.5410
#
# => EARLY STOPPING kích hoạt ở Epoch 33 (Ngừng cải thiện sau 8 epochs).
#
# Quá trình Training hoàn tất trong 782.81 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 4.8023 | Test Macro-F1: 0.5972
#
#               precision    recall  f1-score   support
#
#            0     0.8287    0.8260    0.8273     19846
#            1     1.0000    0.9975    0.9988    484077
#            2     0.9444    1.0000    0.9714      2515
#            3     0.9998    1.0000    0.9999     36253
#            4     0.0902    0.0546    0.0681     18979
#            5     0.0718    1.0000    0.1339      2451
#            6     0.4657    0.9710    0.6294     11847
#            7     0.9995    1.0000    0.9997    107436
#            8     0.4070    0.6440    0.4988     16746
#            9     0.9420    0.0016    0.0031     41523
#           10     0.5054    0.3882    0.4391     18567
#
#     accuracy                         0.8925    760240
#    macro avg     0.6595    0.7166    0.5972    760240
# weighted avg     0.9329    0.8925    0.8835    760240

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 11

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 500.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.4735095  0.01940967 3.740284   0.2591877  0.49517855 3.8380697
#  0.7933406  0.08745643 0.56111133 0.2262908  0.506161  ]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 60
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 8        

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT CHO CẢ ĐỒ THỊ (TĂNG TỐC ĐỘ x20 LẦN!)
        x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER (Tránh Bể RAM)
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
            
            # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
            loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            loss.backward() # Chỉ chạy ngược từ Classifier tới x_ctx_det, SIÊU NHANH
            
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN 1 LẦN DUY NHẤT LÚC ĐÓNG CỬA SỔ
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
            
    avg_train_loss = total_train_loss / total_train_edges
    
    # Validation
    val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
    
    # Bóp Learning Rate dựa theo F1
    scheduler.step(val_f1)
    current_lr = optimizer.param_groups[0]['lr']
    
    print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
    
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        best_model_wts = copy.deepcopy(model.state_dict())
        patience_counter = 0
        print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
            break

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred = evaluate_graphs(model, test_graphs, criterion, device)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}\n")
print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 60 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...
# Epoch  1/60 | LR: 0.001000 | Train Loss: 6.4016 | Val Loss: 5.5509 | Val F1: 0.0716
#    -> Epoch 1: Kỷ lục F1 mới (0.0716)! Đã lưu trọng số.
# Epoch  2/60 | LR: 0.001000 | Train Loss: 5.6411 | Val Loss: 5.4654 | Val F1: 0.0788
#    -> Epoch 2: Kỷ lục F1 mới (0.0788)! Đã lưu trọng số.
# Epoch  3/60 | LR: 0.001000 | Train Loss: 5.3943 | Val Loss: 5.1433 | Val F1: 0.2259
#    -> Epoch 3: Kỷ lục F1 mới (0.2259)! Đã lưu trọng số.
# Epoch  4/60 | LR: 0.001000 | Train Loss: 5.2558 | Val Loss: 5.0598 | Val F1: 0.2881
#    -> Epoch 4: Kỷ lục F1 mới (0.2881)! Đã lưu trọng số.
# Epoch  5/60 | LR: 0.001000 | Train Loss: 5.2477 | Val Loss: 5.0736 | Val F1: 0.1176
# Epoch  6/60 | LR: 0.001000 | Train Loss: 5.2299 | Val Loss: 5.0654 | Val F1: 0.1214
# Epoch  7/60 | LR: 0.000500 | Train Loss: 5.1318 | Val Loss: 4.9910 | Val F1: 0.2868
# Epoch  8/60 | LR: 0.000500 | Train Loss: 5.0255 | Val Loss: 4.9627 | Val F1: 0.2827
# Epoch  9/60 | LR: 0.000500 | Train Loss: 4.9879 | Val Loss: 4.9547 | Val F1: 0.2396
# Epoch 10/60 | LR: 0.000500 | Train Loss: 4.9903 | Val Loss: 4.9630 | Val F1: 0.3237
#    -> Epoch 10: Kỷ lục F1 mới (0.3237)! Đã lưu trọng số.
# Epoch 11/60 | LR: 0.000500 | Train Loss: 4.9791 | Val Loss: 4.9637 | Val F1: 0.2231
# Epoch 12/60 | LR: 0.000500 | Train Loss: 4.9462 | Val Loss: 4.9521 | Val F1: 0.2581
# Epoch 13/60 | LR: 0.000500 | Train Loss: 4.9360 | Val Loss: 4.9483 | Val F1: 0.4229
#    -> Epoch 13: Kỷ lục F1 mới (0.4229)! Đã lưu trọng số.
# Epoch 14/60 | LR: 0.000500 | Train Loss: 4.9223 | Val Loss: 5.0327 | Val F1: 0.3609
# Epoch 15/60 | LR: 0.000500 | Train Loss: 4.8552 | Val Loss: 4.9227 | Val F1: 0.4429
#    -> Epoch 15: Kỷ lục F1 mới (0.4429)! Đã lưu trọng số.
# Epoch 16/60 | LR: 0.000500 | Train Loss: 4.8354 | Val Loss: 4.9392 | Val F1: 0.3112
# Epoch 17/60 | LR: 0.000500 | Train Loss: 4.8039 | Val Loss: 4.8591 | Val F1: 0.5587
#    -> Epoch 17: Kỷ lục F1 mới (0.5587)! Đã lưu trọng số.
# Epoch 18/60 | LR: 0.000500 | Train Loss: 4.7260 | Val Loss: 4.9651 | Val F1: 0.5121
# Epoch 19/60 | LR: 0.000500 | Train Loss: 4.6938 | Val Loss: 4.8161 | Val F1: 0.5877
#    -> Epoch 19: Kỷ lục F1 mới (0.5877)! Đã lưu trọng số.
# Epoch 20/60 | LR: 0.000500 | Train Loss: 4.6697 | Val Loss: 4.8695 | Val F1: 0.5927
#    -> Epoch 20: Kỷ lục F1 mới (0.5927)! Đã lưu trọng số.
# Epoch 21/60 | LR: 0.000500 | Train Loss: 4.6761 | Val Loss: 4.8678 | Val F1: 0.6109
#    -> Epoch 21: Kỷ lục F1 mới (0.6109)! Đã lưu trọng số.
# Epoch 22/60 | LR: 0.000500 | Train Loss: 4.6555 | Val Loss: 4.9019 | Val F1: 0.6627
#    -> Epoch 22: Kỷ lục F1 mới (0.6627)! Đã lưu trọng số.
# Epoch 23/60 | LR: 0.000500 | Train Loss: 4.6381 | Val Loss: 4.7805 | Val F1: 0.6939
#    -> Epoch 23: Kỷ lục F1 mới (0.6939)! Đã lưu trọng số.
# Epoch 24/60 | LR: 0.000500 | Train Loss: 4.6384 | Val Loss: 4.8379 | Val F1: 0.6943
#    -> Epoch 24: Kỷ lục F1 mới (0.6943)! Đã lưu trọng số.
# Epoch 25/60 | LR: 0.000500 | Train Loss: 4.6266 | Val Loss: 4.8674 | Val F1: 0.6514
# Epoch 26/60 | LR: 0.000500 | Train Loss: 4.6136 | Val Loss: 4.8580 | Val F1: 0.6927
# Epoch 27/60 | LR: 0.000250 | Train Loss: 4.6144 | Val Loss: 4.8796 | Val F1: 0.6701
# Epoch 28/60 | LR: 0.000250 | Train Loss: 4.5925 | Val Loss: 4.8913 | Val F1: 0.6436
# Epoch 29/60 | LR: 0.000250 | Train Loss: 4.5900 | Val Loss: 4.8763 | Val F1: 0.6371
# Epoch 30/60 | LR: 0.000125 | Train Loss: 4.5837 | Val Loss: 4.9115 | Val F1: 0.6740
# Epoch 31/60 | LR: 0.000125 | Train Loss: 4.5762 | Val Loss: 4.8845 | Val F1: 0.6351
# Epoch 32/60 | LR: 0.000125 | Train Loss: 4.5730 | Val Loss: 4.8923 | Val F1: 0.6350
#
# => EARLY STOPPING kích hoạt ở Epoch 32 (Ngừng cải thiện sau 8 epochs).
#
# Quá trình Training hoàn tất trong 1202.33 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 4.8100 | Test Macro-F1: 0.5879
#
#               precision    recall  f1-score   support
#
#            0     0.5680    0.8729    0.6882     19846
#            1     1.0000    1.0000    1.0000    484077
#            2     0.1658    1.0000    0.2845      2515
#            3     0.9992    1.0000    0.9996     36253
#            4     0.0000    0.0000    0.0000     18979
#            5     0.2705    0.9996    0.4258      2451
#            6     0.8595    0.9721    0.9123     11847
#            7     1.0000    1.0000    1.0000    107436
#            8     0.4770    0.9814    0.6419     16746
#            9     0.9951    0.0542    0.1027     41523
#           10     0.3443    0.5120    0.4117     18567
#
#     accuracy                         0.9073    760240
#    macro avg     0.6072    0.7629    0.5879    760240
# weighted avg     0.9286    0.9073    0.8900    760240

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 15        

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT CHO CẢ ĐỒ THỊ (TĂNG TỐC ĐỘ x20 LẦN!)
        x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER (Tránh Bể RAM)
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
            
            # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
            loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            loss.backward() # Chỉ chạy ngược từ Classifier tới x_ctx_det, SIÊU NHANH
            
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN 1 LẦN DUY NHẤT LÚC ĐÓNG CỬA SỔ
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
            
    avg_train_loss = total_train_loss / total_train_edges
    
    # Validation
    val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
    
    # Bóp Learning Rate dựa theo F1
    scheduler.step(val_f1)
    current_lr = optimizer.param_groups[0]['lr']
    
    print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
    
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        best_model_wts = copy.deepcopy(model.state_dict())
        patience_counter = 0
        print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
            break

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred = evaluate_graphs(model, test_graphs, criterion, device)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}\n")
print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 6.8921 | Val Loss: 6.1475 | Val F1: 0.0552
#    -> Epoch 1: Kỷ lục F1 mới (0.0552)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 6.8488 | Val Loss: 5.4280 | Val F1: 0.0025
# Epoch  3/100 | LR: 0.001000 | Train Loss: 5.5303 | Val Loss: 5.2777 | Val F1: 0.0821
#    -> Epoch 3: Kỷ lục F1 mới (0.0821)! Đã lưu trọng số.
# Epoch  4/100 | LR: 0.001000 | Train Loss: 5.3894 | Val Loss: 5.1007 | Val F1: 0.2334
#    -> Epoch 4: Kỷ lục F1 mới (0.2334)! Đã lưu trọng số.
# Epoch  5/100 | LR: 0.001000 | Train Loss: 5.4189 | Val Loss: 5.1101 | Val F1: 0.2099
# Epoch  6/100 | LR: 0.001000 | Train Loss: 5.2264 | Val Loss: 5.0756 | Val F1: 0.2193
# Epoch  7/100 | LR: 0.000500 | Train Loss: 5.1666 | Val Loss: 5.0426 | Val F1: 0.2165
# Epoch  8/100 | LR: 0.000500 | Train Loss: 5.1008 | Val Loss: 4.9915 | Val F1: 0.2376
#    -> Epoch 8: Kỷ lục F1 mới (0.2376)! Đã lưu trọng số.
# Epoch  9/100 | LR: 0.000500 | Train Loss: 5.0663 | Val Loss: 4.9817 | Val F1: 0.2087
# Epoch 10/100 | LR: 0.000500 | Train Loss: 5.0701 | Val Loss: 4.9619 | Val F1: 0.3115
#    -> Epoch 10: Kỷ lục F1 mới (0.3115)! Đã lưu trọng số.
# Epoch 11/100 | LR: 0.000500 | Train Loss: 5.0200 | Val Loss: 4.9558 | Val F1: 0.2082
# Epoch 12/100 | LR: 0.000500 | Train Loss: 5.0442 | Val Loss: 4.9524 | Val F1: 0.3487
#    -> Epoch 12: Kỷ lục F1 mới (0.3487)! Đã lưu trọng số.
# Epoch 13/100 | LR: 0.000500 | Train Loss: 5.0102 | Val Loss: 4.9842 | Val F1: 0.2450
# Epoch 14/100 | LR: 0.000500 | Train Loss: 4.9678 | Val Loss: 4.9096 | Val F1: 0.3466
# Epoch 15/100 | LR: 0.000500 | Train Loss: 4.9856 | Val Loss: 4.9160 | Val F1: 0.4261
#    -> Epoch 15: Kỷ lục F1 mới (0.4261)! Đã lưu trọng số.
# Epoch 16/100 | LR: 0.000500 | Train Loss: 4.9057 | Val Loss: 4.9497 | Val F1: 0.3129
# Epoch 17/100 | LR: 0.000500 | Train Loss: 4.8868 | Val Loss: 4.9057 | Val F1: 0.2837
# Epoch 18/100 | LR: 0.000250 | Train Loss: 4.8877 | Val Loss: 4.8957 | Val F1: 0.2619
# Epoch 19/100 | LR: 0.000250 | Train Loss: 4.8099 | Val Loss: 4.8834 | Val F1: 0.4460
#    -> Epoch 19: Kỷ lục F1 mới (0.4460)! Đã lưu trọng số.
# Epoch 20/100 | LR: 0.000250 | Train Loss: 4.7632 | Val Loss: 4.8803 | Val F1: 0.4798
#    -> Epoch 20: Kỷ lục F1 mới (0.4798)! Đã lưu trọng số.
# Epoch 21/100 | LR: 0.000250 | Train Loss: 4.7126 | Val Loss: 4.8705 | Val F1: 0.4466
# Epoch 22/100 | LR: 0.000250 | Train Loss: 4.6860 | Val Loss: 4.8411 | Val F1: 0.5736
#    -> Epoch 22: Kỷ lục F1 mới (0.5736)! Đã lưu trọng số.
# Epoch 23/100 | LR: 0.000250 | Train Loss: 4.6725 | Val Loss: 4.8263 | Val F1: 0.5010
# Epoch 24/100 | LR: 0.000250 | Train Loss: 4.6627 | Val Loss: 4.8328 | Val F1: 0.5159
# Epoch 25/100 | LR: 0.000125 | Train Loss: 4.6575 | Val Loss: 4.7784 | Val F1: 0.5551
# Epoch 26/100 | LR: 0.000125 | Train Loss: 4.6369 | Val Loss: 4.7972 | Val F1: 0.5806
#    -> Epoch 26: Kỷ lục F1 mới (0.5806)! Đã lưu trọng số.
# Epoch 27/100 | LR: 0.000125 | Train Loss: 4.6240 | Val Loss: 4.8091 | Val F1: 0.5796
# Epoch 28/100 | LR: 0.000125 | Train Loss: 4.6205 | Val Loss: 4.8110 | Val F1: 0.5737
# Epoch 29/100 | LR: 0.000063 | Train Loss: 4.6151 | Val Loss: 4.8273 | Val F1: 0.5516
# Epoch 30/100 | LR: 0.000063 | Train Loss: 4.6049 | Val Loss: 4.8119 | Val F1: 0.5964
#    -> Epoch 30: Kỷ lục F1 mới (0.5964)! Đã lưu trọng số.
# Epoch 31/100 | LR: 0.000063 | Train Loss: 4.5998 | Val Loss: 4.8052 | Val F1: 0.5838
# Epoch 32/100 | LR: 0.000063 | Train Loss: 4.5957 | Val Loss: 4.8095 | Val F1: 0.5649
# Epoch 33/100 | LR: 0.000031 | Train Loss: 4.5950 | Val Loss: 4.8117 | Val F1: 0.5755
# Epoch 34/100 | LR: 0.000031 | Train Loss: 4.5911 | Val Loss: 4.8113 | Val F1: 0.5580
# Epoch 35/100 | LR: 0.000031 | Train Loss: 4.5897 | Val Loss: 4.8115 | Val F1: 0.5468
# Epoch 36/100 | LR: 0.000016 | Train Loss: 4.5888 | Val Loss: 4.7980 | Val F1: 0.5568
# Epoch 37/100 | LR: 0.000016 | Train Loss: 4.5872 | Val Loss: 4.8000 | Val F1: 0.5493
# Epoch 38/100 | LR: 0.000016 | Train Loss: 4.5853 | Val Loss: 4.8022 | Val F1: 0.5403
# Epoch 39/100 | LR: 0.000008 | Train Loss: 4.5841 | Val Loss: 4.8045 | Val F1: 0.5451
# Epoch 40/100 | LR: 0.000008 | Train Loss: 4.5837 | Val Loss: 4.8036 | Val F1: 0.5429
# Epoch 41/100 | LR: 0.000008 | Train Loss: 4.5834 | Val Loss: 4.8021 | Val F1: 0.5409
# Epoch 42/100 | LR: 0.000004 | Train Loss: 4.5838 | Val Loss: 4.8021 | Val F1: 0.5415
# Epoch 43/100 | LR: 0.000004 | Train Loss: 4.5835 | Val Loss: 4.8024 | Val F1: 0.5418
# Epoch 44/100 | LR: 0.000004 | Train Loss: 4.5832 | Val Loss: 4.8032 | Val F1: 0.5419
# Epoch 45/100 | LR: 0.000002 | Train Loss: 4.5827 | Val Loss: 4.8038 | Val F1: 0.5420
#
# => EARLY STOPPING kích hoạt ở Epoch 45 (Ngừng cải thiện sau 15 epochs).
#
# Quá trình Training hoàn tất trong 527.13 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 4.7475 | Test Macro-F1: 0.6848
#
#               precision    recall  f1-score   support
#
#            0     0.8083    0.8195    0.8138     19846
#            1     1.0000    0.9967    0.9984    484077
#            2     0.5271    1.0000    0.6904      2515
#            3     0.9992    1.0000    0.9996     36253
#            4     0.4698    0.0759    0.1307     18979
#            5     0.4501    0.9996    0.6207      2451
#            6     0.4041    0.9032    0.5583     11847
#            7     0.9996    1.0000    0.9998    107436
#            8     0.3482    0.7642    0.4784     16746
#            9     0.9990    0.6249    0.7689     41523
#           10     0.6228    0.3816    0.4733     18567
#
#     accuracy                         0.9278    760240
#    macro avg     0.6935    0.7787    0.6848    760240
# weighted avg     0.9454    0.9278    0.9262    760240

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 11

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 500.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.4735095  0.01940967 3.740284   0.2591877  0.49517855 3.8380697
#  0.7933406  0.08745643 0.56111133 0.2262908  0.506161  ]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 15        

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT CHO CẢ ĐỒ THỊ (TĂNG TỐC ĐỘ x20 LẦN!)
        x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER (Tránh Bể RAM)
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
            
            # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
            loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            loss.backward() # Chỉ chạy ngược từ Classifier tới x_ctx_det, SIÊU NHANH
            
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN 1 LẦN DUY NHẤT LÚC ĐÓNG CỬA SỔ
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
            
    avg_train_loss = total_train_loss / total_train_edges
    
    # Validation
    val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
    
    # Bóp Learning Rate dựa theo F1
    scheduler.step(val_f1)
    current_lr = optimizer.param_groups[0]['lr']
    
    print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
    
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        best_model_wts = copy.deepcopy(model.state_dict())
        patience_counter = 0
        print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
            break

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred = evaluate_graphs(model, test_graphs, criterion, device)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}\n")
print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 6.9888 | Val Loss: 5.4910 | Val F1: 0.1286
#    -> Epoch 1: Kỷ lục F1 mới (0.1286)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 5.6320 | Val Loss: 5.2818 | Val F1: 0.0710
# Epoch  3/100 | LR: 0.001000 | Train Loss: 5.5448 | Val Loss: 5.3152 | Val F1: 0.0911
# Epoch  4/100 | LR: 0.000500 | Train Loss: 5.3561 | Val Loss: 5.1791 | Val F1: 0.0999
# Epoch  5/100 | LR: 0.000500 | Train Loss: 5.2314 | Val Loss: 5.0437 | Val F1: 0.1461
#    -> Epoch 5: Kỷ lục F1 mới (0.1461)! Đã lưu trọng số.
# Epoch  6/100 | LR: 0.000500 | Train Loss: 5.1234 | Val Loss: 5.0402 | Val F1: 0.2229
#    -> Epoch 6: Kỷ lục F1 mới (0.2229)! Đã lưu trọng số.
# Epoch  7/100 | LR: 0.000500 | Train Loss: 5.0919 | Val Loss: 4.9663 | Val F1: 0.2431
#    -> Epoch 7: Kỷ lục F1 mới (0.2431)! Đã lưu trọng số.
# Epoch  8/100 | LR: 0.000500 | Train Loss: 5.0603 | Val Loss: 4.9627 | Val F1: 0.2181
# Epoch  9/100 | LR: 0.000500 | Train Loss: 5.0146 | Val Loss: 4.9748 | Val F1: 0.2442
#    -> Epoch 9: Kỷ lục F1 mới (0.2442)! Đã lưu trọng số.
# Epoch 10/100 | LR: 0.000500 | Train Loss: 5.0044 | Val Loss: 4.9026 | Val F1: 0.4483
#    -> Epoch 10: Kỷ lục F1 mới (0.4483)! Đã lưu trọng số.
# Epoch 11/100 | LR: 0.000500 | Train Loss: 4.9453 | Val Loss: 4.9022 | Val F1: 0.3865
# Epoch 12/100 | LR: 0.000500 | Train Loss: 4.9314 | Val Loss: 4.8979 | Val F1: 0.4574
#    -> Epoch 12: Kỷ lục F1 mới (0.4574)! Đã lưu trọng số.
# Epoch 13/100 | LR: 0.000500 | Train Loss: 4.9048 | Val Loss: 4.8787 | Val F1: 0.3748
# Epoch 14/100 | LR: 0.000500 | Train Loss: 4.8386 | Val Loss: 4.9235 | Val F1: 0.2871
# Epoch 15/100 | LR: 0.000500 | Train Loss: 4.8709 | Val Loss: 4.8261 | Val F1: 0.5691
#    -> Epoch 15: Kỷ lục F1 mới (0.5691)! Đã lưu trọng số.
# Epoch 16/100 | LR: 0.000500 | Train Loss: 4.7822 | Val Loss: 4.9867 | Val F1: 0.4037
# Epoch 17/100 | LR: 0.000500 | Train Loss: 4.7802 | Val Loss: 4.8734 | Val F1: 0.4097
# Epoch 18/100 | LR: 0.000250 | Train Loss: 4.7391 | Val Loss: 4.8184 | Val F1: 0.5396
# Epoch 19/100 | LR: 0.000250 | Train Loss: 4.6841 | Val Loss: 4.8132 | Val F1: 0.5677
# Epoch 20/100 | LR: 0.000250 | Train Loss: 4.6726 | Val Loss: 4.8229 | Val F1: 0.5580
# Epoch 21/100 | LR: 0.000250 | Train Loss: 4.6598 | Val Loss: 4.7850 | Val F1: 0.6634
#    -> Epoch 21: Kỷ lục F1 mới (0.6634)! Đã lưu trọng số.
# Epoch 22/100 | LR: 0.000250 | Train Loss: 4.6486 | Val Loss: 4.8033 | Val F1: 0.5889
# Epoch 23/100 | LR: 0.000250 | Train Loss: 4.6461 | Val Loss: 4.8173 | Val F1: 0.6286
# Epoch 24/100 | LR: 0.000125 | Train Loss: 4.6418 | Val Loss: 4.8042 | Val F1: 0.6619
# Epoch 25/100 | LR: 0.000125 | Train Loss: 4.6274 | Val Loss: 4.8063 | Val F1: 0.6787
#    -> Epoch 25: Kỷ lục F1 mới (0.6787)! Đã lưu trọng số.
# Epoch 26/100 | LR: 0.000125 | Train Loss: 4.6247 | Val Loss: 4.8135 | Val F1: 0.6695
# Epoch 27/100 | LR: 0.000125 | Train Loss: 4.6221 | Val Loss: 4.8156 | Val F1: 0.6632
# Epoch 28/100 | LR: 0.000063 | Train Loss: 4.6182 | Val Loss: 4.8125 | Val F1: 0.6662
# Epoch 29/100 | LR: 0.000063 | Train Loss: 4.6160 | Val Loss: 4.8180 | Val F1: 0.6479
# Epoch 30/100 | LR: 0.000063 | Train Loss: 4.6135 | Val Loss: 4.8197 | Val F1: 0.6396
# Epoch 31/100 | LR: 0.000031 | Train Loss: 4.6089 | Val Loss: 4.8123 | Val F1: 0.6580
# Epoch 32/100 | LR: 0.000031 | Train Loss: 4.6071 | Val Loss: 4.8125 | Val F1: 0.6504
# Epoch 33/100 | LR: 0.000031 | Train Loss: 4.6062 | Val Loss: 4.8139 | Val F1: 0.6519
# Epoch 34/100 | LR: 0.000016 | Train Loss: 4.6060 | Val Loss: 4.8113 | Val F1: 0.6518
# Epoch 35/100 | LR: 0.000016 | Train Loss: 4.6040 | Val Loss: 4.8122 | Val F1: 0.6520
# Epoch 36/100 | LR: 0.000016 | Train Loss: 4.6029 | Val Loss: 4.8129 | Val F1: 0.6522
# Epoch 37/100 | LR: 0.000008 | Train Loss: 4.6028 | Val Loss: 4.8123 | Val F1: 0.6522
# Epoch 38/100 | LR: 0.000008 | Train Loss: 4.6017 | Val Loss: 4.8127 | Val F1: 0.6523
# Epoch 39/100 | LR: 0.000008 | Train Loss: 4.6024 | Val Loss: 4.8130 | Val F1: 0.6523
# Epoch 40/100 | LR: 0.000004 | Train Loss: 4.6017 | Val Loss: 4.8124 | Val F1: 0.6524
#
# => EARLY STOPPING kích hoạt ở Epoch 40 (Ngừng cải thiện sau 15 epochs).
#
# Quá trình Training hoàn tất trong 472.03 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 4.7281 | Test Macro-F1: 0.7305
#
#               precision    recall  f1-score   support
#
#            0     0.6674    0.7957    0.7259     19846
#            1     1.0000    0.9984    0.9992    484077
#            2     0.8963    1.0000    0.9453      2515
#            3     0.9970    1.0000    0.9985     36253
#            4     0.3111    0.1439    0.1968     18979
#            5     0.6128    1.0000    0.7599      2451
#            6     0.4960    0.9720    0.6568     11847
#            7     1.0000    0.9980    0.9990    107436
#            8     0.4367    0.9968    0.6073     16746
#            9     0.9997    0.6667    0.7999     41523
#           10     0.8256    0.2199    0.3472     18567
#
#     accuracy                         0.9343    760240
#    macro avg     0.7493    0.7992    0.7305    760240
# weighted avg     0.9478    0.9343    0.9303    760240
